# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import scipy.stats as st
from scipy.stats import linregress
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
print(weather_api_key)
# Out:
# b92591705d4ffeecbb0b498e07c30086

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Build URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" 
api_key = "b92591705d4ffeecbb0b498e07c30086"
appid = api_key
settings = {"units": "imperial", "appid": api_key}
url = f"{url}appid={api_key}&units={units}"

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_latitute = city_weather["coord"]["lat"]
        city_longitude = city_weather["coord"]["lon"]
        city_max_temperature = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_latitute, 
                          "Lng": city_longitude, 
                          "Max Temp": city_max_temperature,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# i
# Processing Record 49 of Set 10 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=comodoro%20rivadavia
# Processing Record 0 of Set 11 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=ulaanbaatar
# Processing Record 1 of Set 11 | samarinda
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=samarinda
# Processing Record 2 of Set 11 | shitanjing
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=shitanjing
# Processing Record 3 of Set 11 | novopokrovka
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=novopokrovka
# Processing Record 4 of Set 11 | porto novo
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=porto%20novo
# Processing Record 5 of Set 11 | robertsport
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=robertsport
# Processing Record 6 of Set 11 | borgarnes
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=borgarnes
# Processing Record 7 of Set 11 | sao sebastiao
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=sao%20sebastiao
# Processing Record 8 of Set 11 | yangjiang
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=yangjiang
# Processing Record 9 of Set 11 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bilma
# Processing Record 10 of Set 11 | isabela
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=isabela
# Processing Record 11 of Set 11 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=coquimbo
# Processing Record 12 of Set 11 | ukiah
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=ukiah
# Processing Record 13 of Set 11 | nenjiang
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=nenjiang
# Processing Record 14 of Set 11 | roma
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=roma
# Processing Record 15 of Set 11 | lagunas
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=lagunas
# Processing Record 16 of Set 11 | staronizhestebliyevskaya
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=staronizhestebliyevskaya
# Processing Record 17 of Set 11 | bosaso
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bosaso
# Processing Record 18 of Set 11 | nekhayevskiy
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=nekhayevskiy
# Processing Record 19 of Set 11 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=cayenne
# Processing Record 20 of Set 11 | khonuu
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=khonuu
# City not found...
# Processing Record 21 of Set 11 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=batticaloa
# Processing Record 22 of Set 11 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=myitkyina
# Processing Record 23 of Set 11 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=arlit
# Processing Record 24 of Set 11 | maxixe
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=maxixe
# Processing Record 25 of Set 11 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=hobyo
# Processing Record 26 of Set 11 | tay ninh
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=tay%20ninh
# Processing Record 27 of Set 11 | canavieiras
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=canavieiras
# Processing Record 28 of Set 11 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=souillac
# Processing Record 29 of Set 11 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=verkhnyaya%20inta
# Processing Record 30 of Set 11 | bababe
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bababe
# City not found...
# Processing Record 31 of Set 11 | tateyama
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=tateyama
# Processing Record 32 of Set 11 | alotau
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=alotau
# City not found...
# Processing Record 33 of Set 11 | puerto castilla
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=puerto%20castilla
# Processing Record 34 of Set 11 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=samarai
# Processing Record 35 of Set 11 | bogovarovo
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bogovarovo
# Processing Record 36 of Set 11 | adeje
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=adeje
# Processing Record 37 of Set 11 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=virginia%20beach
# Processing Record 38 of Set 11 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=ust-tsilma
# Processing Record 39 of Set 11 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=puerto%20escondido
# Processing Record 40 of Set 11 | santiago del estero
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=santiago%20del%20estero
# Processing Record 41 of Set 11 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=chapais
# Processing Record 42 of Set 11 | tromso
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=tromso
# Processing Record 43 of Set 11 | lynn haven
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=lynn%20haven
# Processing Record 44 of Set 11 | we
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=we
# City not found...
# Processing Record 45 of Set 11 | bongandanga
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bongandanga
# Processing Record 46 of Set 11 | suicheng
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=suicheng
# Processing Record 47 of Set 11 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=atambua
# Processing Record 48 of Set 11 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=mayo
# Processing Record 49 of Set 11 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=victor%20harbor
# Processing Record 0 of Set 12 | chengam
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=chengam
# Processing Record 1 of Set 12 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=sao%20jose%20da%20coroa%20grande
# Processing Record 2 of Set 12 | herat
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=herat
# Processing Record 3 of Set 12 | saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=saleaula
# City not found...
# Processing Record 4 of Set 12 | aketi
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=aketi
# Processing Record 5 of Set 12 | hirson
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=hirson
# Processing Record 6 of Set 12 | ravar
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=ravar
# Processing Record 7 of Set 12 | evora
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=evora
# Processing Record 8 of Set 12 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=dunedin
# Processing Record 9 of Set 12 | galle
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=galle
# Processing Record 10 of Set 12 | nicoya
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=nicoya
# Processing Record 11 of Set 12 | guajara-mirim
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=guajara-mirim
# City not found...
# Processing Record 12 of Set 12 | labutta
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=labutta
# City not found...
# Processing Record 13 of Set 12 | inirida
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=inirida
# Processing Record 14 of Set 12 | ngerengere
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=ngerengere
# Processing Record 15 of Set 12 | morwell
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=morwell
# Processing Record 16 of Set 12 | ongandjera
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=ongandjera
# Processing Record 17 of Set 12 | acarau
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=acarau
# Processing Record 18 of Set 12 | guayaramerin
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=guayaramerin
# Processing Record 19 of Set 12 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=thunder%20bay
# Processing Record 20 of Set 12 | alpine
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=alpine
# Processing Record 21 of Set 12 | vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=vanimo
# Processing Record 22 of Set 12 | mana
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=mana
# Processing Record 23 of Set 12 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=blagoyevo
# Processing Record 24 of Set 12 | jawhar
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=jawhar
# Processing Record 25 of Set 12 | kidal
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=kidal
# Processing Record 26 of Set 12 | barentu
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=barentu
# Processing Record 27 of Set 12 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=richards%20bay
# Processing Record 28 of Set 12 | birao
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=birao
# Processing Record 29 of Set 12 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=hovd
# Processing Record 30 of Set 12 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=dicabisagan
# Processing Record 31 of Set 12 | voznesenye
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=voznesenye
# Processing Record 32 of Set 12 | mihailesti
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=mihailesti
# Processing Record 33 of Set 12 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bac%20lieu
# Processing Record 34 of Set 12 | pierre
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=pierre
# Processing Record 35 of Set 12 | bageshwar
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bageshwar
# Processing Record 36 of Set 12 | cedral
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=cedral
# Processing Record 37 of Set 12 | san jose de guanipa
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=san%20jose%20de%20guanipa
# Processing Record 38 of Set 12 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=taoudenni
# Processing Record 39 of Set 12 | conakry
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=conakry
# Processing Record 40 of Set 12 | mendahara
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=mendahara
# City not found...
# Processing Record 41 of Set 12 | sidi ali
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=sidi%20ali
# Processing Record 42 of Set 12 | bangui
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=bangui
# Processing Record 43 of Set 12 | barguzin
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=barguzin
# Processing Record 44 of Set 12 | manzhouli
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=manzhouli
# Processing Record 45 of Set 12 | medea
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=medea
# Processing Record 46 of Set 12 | darnah
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=darnah
# Processing Record 47 of Set 12 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=marsh%20harbour
# Processing Record 48 of Set 12 | anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=anadyr
# Processing Record 49 of Set 12 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=tual
# Processing Record 0 of Set 13 | shcholkine
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=shcholkine
# City not found...
# Processing Record 1 of Set 13 | samana
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=samana
# Processing Record 2 of Set 13 | marihatag
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=marihatag
# Processing Record 3 of Set 13 | sangar
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=sangar
# Processing Record 4 of Set 13 | arica
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=arica
# Processing Record 5 of Set 13 | seguela
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=seguela
# Processing Record 6 of Set 13 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=kemijarvi
# Processing Record 7 of Set 13 | karakose
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=karakose
# City not found...
# Processing Record 8 of Set 13 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=meulaboh
# Processing Record 9 of Set 13 | capaccio
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=capaccio
# Processing Record 10 of Set 13 | babanusah
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=babanusah
# City not found...
# Processing Record 11 of Set 13 | cambrai
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=cambrai
# Processing Record 12 of Set 13 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=kununurra
# Processing Record 13 of Set 13 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=zyryanka
# Processing Record 14 of Set 13 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=sao%20joao%20da%20barra
# Processing Record 15 of Set 13 | marquette
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=marquette
# Processing Record 16 of Set 13 | troitskoye
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=troitskoye
# Processing Record 17 of Set 13 | jos
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=jos
# Processing Record 18 of Set 13 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=itarema
# Processing Record 19 of Set 13 | catuday
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=catuday
# Processing Record 20 of Set 13 | soe
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=soe
# Processing Record 21 of Set 13 | kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=kyzyl-suu
# Processing Record 22 of Set 13 | namanga
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=namanga
# Processing Record 23 of Set 13 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=pemangkat
# Processing Record 24 of Set 13 | ituni
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=ituni
# City not found...
# Processing Record 25 of Set 13 | asosa
# http://api.openweathermap.org/data/2.5/weather?appid=b92591705d4ffeecbb0b498e07c30086&units=imperial&q=asosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Export the City_Data into a csv
city_data_pd.to_csv("WeatherPy.csv",encoding="utf-8",index=False)


# Show Record Count
city_data_pd.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display the DataFrame
city_data_pd.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  emerald -23.5333  148.1667     62.60        77          45        3.44
# 1   kampot  10.6167  104.1833     78.80       100          20        4.61
# 2   torbay  47.6666  -52.7314     44.01        65          75       26.46
# 3  iquitos  -3.7481  -73.2472     87.80        66          75        4.61
# 4    kapaa  22.0752 -159.3190     78.80        65          20       12.66
#
#   Country        Date
# 0      AU  1620071218
# 1      KH  1620071219
# 2      CA  1620071219
# 3      PE  1620071219
# 4      US  1620071219

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Max Temp"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig('../Images/Latitude vs Temperature (F).png')

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Humidity"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig('../Images/Latitude vs Humidity (%).png')

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig('../Images/Latitude vs Cloudiness (%).png')

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig('../Images/Latitude vs Wind Speed (MPH).png')

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = city_data_pd.loc[city_data_pd["Lat"] >= 0]
southern_hemisphere = city_data_pd.loc[city_data_pd["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 20)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.86

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig('../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png')
# Out:
# The r-squared is : 0.69

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.0

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig('../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png')
# Out:
# The r-squared is : 0.27

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.08

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.1

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.14

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.28
