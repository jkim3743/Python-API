# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

#Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %% [markdown]
# ### Perform API Calls

# %%
# Starting URL for Weather Map API call
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
# Print (url)


# List of City Data
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print ("-" * 15)


# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in list
for index, city in enumerate(cities):
    # Group cities in sets of 50 for loggin purpose
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    
    # Log the URL and set number
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Extract out max temp humidity and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the city info into the city data list
        city_data.append({
            "City" :city,
            "Lat" :city_lat,
            "Lng" :city_lng,
            "Max Temp" :city_max_temp,
            "Humidity" :city_humidity,
            "Cloudiness" :city_clouds,
            "Windspeed" :city_wind,
            "Country" :city_country,
            "Date" :city_date  
        })
    except:
        print("City not found. Skipping ...")
        pass
    # Indicate that data loading is complete
        print("-----------------------")
        print("Data Retrieval Complete")
        print("-----------------------")
# Out:
# Beginning Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | arlit
# Processing Record 7 of Set 1 | ellisras
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | turangi
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | mkushi
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | yeehaw junction
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | saleaula
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | manokwari
# Processing Record 23 of Set 1 | kabanjahe
# Processing Record 24 of Set 1 | rocha
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | rabat
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | ambilobe
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | saint-augustin
# Processing Record 33 of Set 1 | amapa
# Processing Record 34 of Set 1 | oranjestad
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | surt
# Processing Record 37 of Set 1 | kralendijk
# Processing Record 38 of Set 1 | bandarbeyla
# Processing Record 39 of Set 1 | karratha
# Processing Record 40 of Set 1 | kokstad
# Processing Record 41 of Set 1 | portland
# Processing Record 42 of Set 1 | vostok
# Processing Record 43 of Set 1 | green valley
# Processing Record 44 of Set 1 | cristobal obregon
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | yar-sale
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | chicama
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 0 of Set 2 | katangli
# Processing Record 1 of Set 2 | balabac
# Processing Record 2 of Set 2 | makakilo city
# Processing Record 3 of Set 2 | westport
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 2 | terney
# Processing Record 6 of Set 2 | cortez
# Processing Record 7 of Set 2 | lagos
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | praia
# Processing Record 10 of Set 2 | nikolskoye
# Processing Record 11 of Set 2 | pisco
# Processing Record 12 of Set 2 | san francisco
# Processing Record 13 of Set 2 | nishihara
# Processing Record 14 of Set 2 | hailar
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | mnogovershinnyy
# Processing Record 20 of Set 2 | caluquembe
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | shimoda
# Processing Record 23 of Set 2 | marsabit
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | qinggang
# Processing Record 31 of Set 2 | ust-bolsheretsk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | aransas pass
# Processing Record 35 of Set 2 | puerto lopez
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 37 of Set 2 | isangel
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | saint-pacome
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 2 | cayenne
# Processing Record 43 of Set 2 | constantine
# Processing Record 44 of Set 2 | balkanabat
# Processing Record 45 of Set 2 | saint anthony
# Processing Record 46 of Set 2 | nylstroom
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 47 of Set 2 | tumannyy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 48 of Set 2 | sampit
# Processing Record 49 of Set 2 | upernavik
# Processing Record 0 of Set 3 | ostrovnoy
# Processing Record 1 of Set 3 | jingdezhen
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | churapcha
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | olafsvik
# Processing Record 6 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 3 | heihe
# Processing Record 8 of Set 3 | bastos
# Processing Record 9 of Set 3 | poso
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | kangaatsiaq
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | katsuura
# Processing Record 14 of Set 3 | srostki
# Processing Record 15 of Set 3 | tiznit
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | paso de los toros
# Processing Record 18 of Set 3 | houma
# Processing Record 19 of Set 3 | taolanaro
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 20 of Set 3 | santa isabel do rio negro
# Processing Record 21 of Set 3 | saint-denis
# Processing Record 22 of Set 3 | nancha
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | belushya guba
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 26 of Set 3 | dunmore east
# Processing Record 27 of Set 3 | klaksvik
# Processing Record 28 of Set 3 | coquimbo
# Processing Record 29 of Set 3 | cuamba
# Processing Record 30 of Set 3 | palabuhanratu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 3 | cape town
# Processing Record 32 of Set 3 | saint-francois
# Processing Record 33 of Set 3 | oriximina
# Processing Record 34 of Set 3 | alotau
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 3 | bara
# Processing Record 36 of Set 3 | caucaia
# Processing Record 37 of Set 3 | gangotri
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | anadyr
# Processing Record 40 of Set 3 | bubaque
# Processing Record 41 of Set 3 | luang prabang
# Processing Record 42 of Set 3 | nguiu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 43 of Set 3 | tevaitoa
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | boffa
# Processing Record 46 of Set 3 | novoagansk
# Processing Record 47 of Set 3 | adrar
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | san quintin
# Processing Record 0 of Set 4 | kieta
# Processing Record 1 of Set 4 | husavik
# Processing Record 2 of Set 4 | anaconda
# Processing Record 3 of Set 4 | sabang
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | kapit
# Processing Record 7 of Set 4 | lorengau
# Processing Record 8 of Set 4 | ca mau
# Processing Record 9 of Set 4 | fairbanks
# Processing Record 10 of Set 4 | kobelyaky
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | pacific grove
# Processing Record 13 of Set 4 | half moon bay
# Processing Record 14 of Set 4 | dale city
# Processing Record 15 of Set 4 | quatre cocos
# Processing Record 16 of Set 4 | vega de alatorre
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | wukari
# Processing Record 19 of Set 4 | port hardy
# Processing Record 20 of Set 4 | keskin
# Processing Record 21 of Set 4 | okhotsk
# Processing Record 22 of Set 4 | guerrero negro
# Processing Record 23 of Set 4 | taltal
# Processing Record 24 of Set 4 | waipawa
# Processing Record 25 of Set 4 | qostanay
# Processing Record 26 of Set 4 | orocue
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | plettenberg bay
# Processing Record 29 of Set 4 | salmon arm
# Processing Record 30 of Set 4 | attawapiskat
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 4 | mombetsu
# Processing Record 32 of Set 4 | havelock
# Processing Record 33 of Set 4 | kjollefjord
# Processing Record 34 of Set 4 | shawnee
# Processing Record 35 of Set 4 | beipiao
# Processing Record 36 of Set 4 | alofi
# Processing Record 37 of Set 4 | jamestown
# Processing Record 38 of Set 4 | guiyang
# Processing Record 39 of Set 4 | xai-xai
# Processing Record 40 of Set 4 | batavia
# Processing Record 41 of Set 4 | kelowna
# Processing Record 42 of Set 4 | goderich
# Processing Record 43 of Set 4 | lamu
# Processing Record 44 of Set 4 | avera
# Processing Record 45 of Set 4 | cherskiy
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | hudson bay
# Processing Record 49 of Set 4 | touros
# Processing Record 0 of Set 5 | neyvo-shaytanskiy
# Processing Record 1 of Set 5 | ballina
# Processing Record 2 of Set 5 | manavalakurichi
# Processing Record 3 of Set 5 | college
# Processing Record 4 of Set 5 | havre-saint-pierre
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | nizhnyaya poyma
# Processing Record 8 of Set 5 | tiarei
# Processing Record 9 of Set 5 | severnoye
# Processing Record 10 of Set 5 | port hedland
# Processing Record 11 of Set 5 | tromso
# Processing Record 12 of Set 5 | lalmohan
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | paciran
# Processing Record 15 of Set 5 | salisbury
# Processing Record 16 of Set 5 | caravelas
# Processing Record 17 of Set 5 | pangnirtung
# Processing Record 18 of Set 5 | kununurra
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | nanortalik
# Processing Record 21 of Set 5 | sitka
# Processing Record 22 of Set 5 | jalu
# Processing Record 23 of Set 5 | iberia
# Processing Record 24 of Set 5 | fray bentos
# Processing Record 25 of Set 5 | fenoarivo
# Processing Record 26 of Set 5 | harper
# Processing Record 27 of Set 5 | codrington
# Processing Record 28 of Set 5 | chernyshevskiy
# Processing Record 29 of Set 5 | marawi
# Processing Record 30 of Set 5 | zhuanghe
# Processing Record 31 of Set 5 | avarua
# Processing Record 32 of Set 5 | ahipara
# Processing Record 33 of Set 5 | sobolevo
# Processing Record 34 of Set 5 | paamiut
# Processing Record 35 of Set 5 | dingle
# Processing Record 36 of Set 5 | waingapu
# Processing Record 37 of Set 5 | qaqortoq
# Processing Record 38 of Set 5 | naze
# Processing Record 39 of Set 5 | yellowknife
# Processing Record 40 of Set 5 | bhuban
# Processing Record 41 of Set 5 | edd
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | buwenge
# Processing Record 44 of Set 5 | ruatoria
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 45 of Set 5 | taywarah
# Processing Record 46 of Set 5 | coahuayana
# Processing Record 47 of Set 5 | urdoma
# Processing Record 48 of Set 5 | joshimath
# Processing Record 49 of Set 5 | dwarka
# Processing Record 0 of Set 6 | kupang
# Processing Record 1 of Set 6 | walvis bay
# Processing Record 2 of Set 6 | grand river south east
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 3 of Set 6 | kavaratti
# Processing Record 4 of Set 6 | rungata
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 6 | rio grande
# Processing Record 6 of Set 6 | mount isa
# Processing Record 7 of Set 6 | medea
# Processing Record 8 of Set 6 | dubbo
# Processing Record 9 of Set 6 | valenca
# Processing Record 10 of Set 6 | turochak
# Processing Record 11 of Set 6 | nioro
# Processing Record 12 of Set 6 | celestun
# Processing Record 13 of Set 6 | nouakchott
# Processing Record 14 of Set 6 | katobu
# Processing Record 15 of Set 6 | siloam springs
# Processing Record 16 of Set 6 | beruwala
# Processing Record 17 of Set 6 | ukiah
# Processing Record 18 of Set 6 | ust-nera
# Processing Record 19 of Set 6 | homagama
# Processing Record 20 of Set 6 | constitucion
# Processing Record 21 of Set 6 | koslan
# Processing Record 22 of Set 6 | kisanga
# Processing Record 23 of Set 6 | dongying
# Processing Record 24 of Set 6 | banjar
# Processing Record 25 of Set 6 | juan lacaze
# Processing Record 26 of Set 6 | vaitupu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 27 of Set 6 | port macquarie
# Processing Record 28 of Set 6 | lazaro cardenas
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | fortuna
# Processing Record 31 of Set 6 | san juan evangelista
# Processing Record 32 of Set 6 | lac du bonnet
# Processing Record 33 of Set 6 | romny
# Processing Record 34 of Set 6 | itoman
# Processing Record 35 of Set 6 | samarai
# Processing Record 36 of Set 6 | morrope
# Processing Record 37 of Set 6 | nkayi
# Processing Record 38 of Set 6 | vila do maio
# Processing Record 39 of Set 6 | kehtna
# Processing Record 40 of Set 6 | ilhabela
# Processing Record 41 of Set 6 | hambantota
# Processing Record 42 of Set 6 | aromashevo
# Processing Record 43 of Set 6 | sao joao da barra
# Processing Record 44 of Set 6 | gamba
# Processing Record 45 of Set 6 | turukhansk
# Processing Record 46 of Set 6 | pirovskoye
# Processing Record 47 of Set 6 | tubuala
# Processing Record 48 of Set 6 | karasburg
# Processing Record 49 of Set 6 | businga
# Processing Record 0 of Set 7 | maturin
# Processing Record 1 of Set 7 | pitimbu
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | ugoofaaru
# Processing Record 4 of Set 7 | cantaura
# Processing Record 5 of Set 7 | veraval
# Processing Record 6 of Set 7 | griffith
# Processing Record 7 of Set 7 | uwajima
# Processing Record 8 of Set 7 | marystown
# Processing Record 9 of Set 7 | eskilstuna
# Processing Record 10 of Set 7 | faya
# Processing Record 11 of Set 7 | hualmay
# Processing Record 12 of Set 7 | nakajo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 13 of Set 7 | tual
# Processing Record 14 of Set 7 | luderitz
# Processing Record 15 of Set 7 | bekhtery
# Processing Record 16 of Set 7 | iqaluit
# Processing Record 17 of Set 7 | lokosovo
# Processing Record 18 of Set 7 | senigallia
# Processing Record 19 of Set 7 | haines junction
# Processing Record 20 of Set 7 | yulara
# Processing Record 21 of Set 7 | ayan
# Processing Record 22 of Set 7 | santa fe
# Processing Record 23 of Set 7 | homer
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | oliver
# Processing Record 26 of Set 7 | acajutla
# Processing Record 27 of Set 7 | bria
# Processing Record 28 of Set 7 | jardim
# Processing Record 29 of Set 7 | severnyy
# Processing Record 30 of Set 7 | hasaki
# Processing Record 31 of Set 7 | albertville
# Processing Record 32 of Set 7 | talara
# Processing Record 33 of Set 7 | pozo colorado
# Processing Record 34 of Set 7 | orlik
# Processing Record 35 of Set 7 | bedele
# Processing Record 36 of Set 7 | paso blanco
# Processing Record 37 of Set 7 | leeton
# Processing Record 38 of Set 7 | coihaique
# Processing Record 39 of Set 7 | tsihombe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 7 | susanville
# Processing Record 41 of Set 7 | wattegama
# Processing Record 42 of Set 7 | tagusao
# Processing Record 43 of Set 7 | lagoa
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | souillac
# Processing Record 46 of Set 7 | aykhal
# Processing Record 47 of Set 7 | te anau
# Processing Record 48 of Set 7 | lishu
# Processing Record 49 of Set 7 | eskasem
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 0 of Set 8 | blagoyevo
# Processing Record 1 of Set 8 | seminole
# Processing Record 2 of Set 8 | morgan city
# Processing Record 3 of Set 8 | neuruppin
# Processing Record 4 of Set 8 | whitehorse
# Processing Record 5 of Set 8 | north bend
# Processing Record 6 of Set 8 | gigmoto
# Processing Record 7 of Set 8 | prince rupert
# Processing Record 8 of Set 8 | haftoni
# Processing Record 9 of Set 8 | yarmouth
# Processing Record 10 of Set 8 | thompson
# Processing Record 11 of Set 8 | tiksi
# Processing Record 12 of Set 8 | canitas
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 13 of Set 8 | novovarshavka
# Processing Record 14 of Set 8 | sofiysk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 8 | ancud
# Processing Record 16 of Set 8 | maxixe
# Processing Record 17 of Set 8 | merrill
# Processing Record 18 of Set 8 | ibaiti
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | izumo
# Processing Record 22 of Set 8 | aljezur
# Processing Record 23 of Set 8 | lebedinyy
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | las conchas
# Processing Record 26 of Set 8 | kampong thum
# Processing Record 27 of Set 8 | louisbourg
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 28 of Set 8 | lasa
# Processing Record 29 of Set 8 | ochakiv
# Processing Record 30 of Set 8 | taburi
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 8 | tearce
# Processing Record 32 of Set 8 | nobres
# Processing Record 33 of Set 8 | norden
# Processing Record 34 of Set 8 | sentyabrskiy
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 8 | port hawkesbury
# Processing Record 36 of Set 8 | flin flon
# Processing Record 37 of Set 8 | aberdeen
# Processing Record 38 of Set 8 | coruripe
# Processing Record 39 of Set 8 | tuktoyaktuk
# Processing Record 40 of Set 8 | aksarka
# Processing Record 41 of Set 8 | fomboni
# Processing Record 42 of Set 8 | grand centre
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 43 of Set 8 | menongue
# Processing Record 44 of Set 8 | sayat
# Processing Record 45 of Set 8 | mae sai
# Processing Record 46 of Set 8 | umm durman
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 47 of Set 8 | bud
# Processing Record 48 of Set 8 | havoysund
# Processing Record 49 of Set 8 | inverell
# Processing Record 0 of Set 9 | el vendrell
# Processing Record 1 of Set 9 | yeppoon
# Processing Record 2 of Set 9 | ivanteyevka
# Processing Record 3 of Set 9 | srednekolymsk
# Processing Record 4 of Set 9 | chapleau
# Processing Record 5 of Set 9 | sanski most
# Processing Record 6 of Set 9 | bogande
# Processing Record 7 of Set 9 | pecangakan
# Processing Record 8 of Set 9 | eyl
# Processing Record 9 of Set 9 | zhucheng
# Processing Record 10 of Set 9 | grand gaube
# Processing Record 11 of Set 9 | nyurba
# Processing Record 12 of Set 9 | andenes
# Processing Record 13 of Set 9 | vicuna
# Processing Record 14 of Set 9 | cardinal
# Processing Record 15 of Set 9 | urumqi
# Processing Record 16 of Set 9 | basco
# Processing Record 17 of Set 9 | comodoro rivadavia
# Processing Record 18 of Set 9 | baringo
# Processing Record 19 of Set 9 | daru
# Processing Record 20 of Set 9 | mandalgovi
# Processing Record 21 of Set 9 | salinas
# Processing Record 22 of Set 9 | brumunddal
# Processing Record 23 of Set 9 | ust-kut
# Processing Record 24 of Set 9 | centerville
# Processing Record 25 of Set 9 | mehamn
# Processing Record 26 of Set 9 | alice springs
# Processing Record 27 of Set 9 | san patricio
# Processing Record 28 of Set 9 | yichang
# Processing Record 29 of Set 9 | vao
# Processing Record 30 of Set 9 | eureka
# Processing Record 31 of Set 9 | misratah
# Processing Record 32 of Set 9 | bababe
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 33 of Set 9 | saldanha
# Processing Record 34 of Set 9 | east massapequa
# Processing Record 35 of Set 9 | ust-kamchatsk
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 36 of Set 9 | grojec
# Processing Record 37 of Set 9 | kashi
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | chazuta
# Processing Record 40 of Set 9 | narsaq
# Processing Record 41 of Set 9 | yumen
# Processing Record 42 of Set 9 | marathon
# Processing Record 43 of Set 9 | bitung
# Processing Record 44 of Set 9 | shelburne
# Processing Record 45 of Set 9 | nome
# Processing Record 46 of Set 9 | bonavista
# Processing Record 47 of Set 9 | moscow
# Processing Record 48 of Set 9 | gua musang
# Processing Record 49 of Set 9 | finschhafen
# Processing Record 0 of Set 10 | pundaguitan
# Processing Record 1 of Set 10 | vestmanna
# Processing Record 2 of Set 10 | zelenchukskaya
# Processing Record 3 of Set 10 | imbituba
# Processing Record 4 of Set 10 | victoria
# Processing Record 5 of Set 10 | asosa
# Processing Record 6 of Set 10 | khonuu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 7 of Set 10 | talnakh
# Processing Record 8 of Set 10 | the valley
# Processing Record 9 of Set 10 | chengam
# Processing Record 10 of Set 10 | puerto colombia
# Processing Record 11 of Set 10 | virginia beach
# Processing Record 12 of Set 10 | alta floresta
# Processing Record 13 of Set 10 | saint-pierre
# Processing Record 14 of Set 10 | bambous virieux
# Processing Record 15 of Set 10 | lata
# Processing Record 16 of Set 10 | mmabatho
# Processing Record 17 of Set 10 | praya
# Processing Record 18 of Set 10 | puerto carreno
# Processing Record 19 of Set 10 | vila franca do campo
# Processing Record 20 of Set 10 | xucheng
# Processing Record 21 of Set 10 | santiago del estero
# Processing Record 22 of Set 10 | mo i rana
# Processing Record 23 of Set 10 | kamiiso
# Processing Record 24 of Set 10 | maloshuyka
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 25 of Set 10 | requena
# Processing Record 26 of Set 10 | boca do acre
# Processing Record 27 of Set 10 | aklavik
# Processing Record 28 of Set 10 | oussouye
# Processing Record 29 of Set 10 | birao
# Processing Record 30 of Set 10 | isabela
# Processing Record 31 of Set 10 | parrita
# Processing Record 32 of Set 10 | burgeo
# Processing Record 33 of Set 10 | schoneiche
# Processing Record 34 of Set 10 | sambava
# Processing Record 35 of Set 10 | salalah
# Processing Record 36 of Set 10 | addi ugri
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 37 of Set 10 | gat
# Processing Record 38 of Set 10 | santiago de cao
# Processing Record 39 of Set 10 | nouadhibou
# Processing Record 40 of Set 10 | cabo rojo
# Processing Record 41 of Set 10 | kahului
# Processing Record 42 of Set 10 | policoro
# Processing Record 43 of Set 10 | shirokiy
# Processing Record 44 of Set 10 | koroni
# Processing Record 45 of Set 10 | vredendal
# Processing Record 46 of Set 10 | muncar
# Processing Record 47 of Set 10 | abha
# Processing Record 48 of Set 10 | cabedelo
# Processing Record 49 of Set 10 | maltahohe
# Processing Record 0 of Set 11 | vanimo
# Processing Record 1 of Set 11 | general roca
# Processing Record 2 of Set 11 | tezu
# Processing Record 3 of Set 11 | kuche
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 4 of Set 11 | mazagao
# Processing Record 5 of Set 11 | zhengjiatun
# Processing Record 6 of Set 11 | mahon
# Processing Record 7 of Set 11 | nuuk
# Processing Record 8 of Set 11 | boromo
# Processing Record 9 of Set 11 | yaan
# Processing Record 10 of Set 11 | kovdor
# Processing Record 11 of Set 11 | aripuana
# Processing Record 12 of Set 11 | biak
# Processing Record 13 of Set 11 | zeya
# Processing Record 14 of Set 11 | guymon
# Processing Record 15 of Set 11 | loreto
# Processing Record 16 of Set 11 | tura
# Processing Record 17 of Set 11 | san-pedro
# Processing Record 18 of Set 11 | zhoucheng
# Processing Record 19 of Set 11 | carutapera
# Processing Record 20 of Set 11 | vila
# Processing Record 21 of Set 11 | spasskoye
# Processing Record 22 of Set 11 | bulgan
# Processing Record 23 of Set 11 | san cristobal
# Processing Record 24 of Set 11 | shibetsu
# Processing Record 25 of Set 11 | yanam
# Processing Record 26 of Set 11 | airai
# Processing Record 27 of Set 11 | carmen
# Processing Record 28 of Set 11 | bakchar
# Processing Record 29 of Set 11 | lenger
# Processing Record 30 of Set 11 | normal
# Processing Record 31 of Set 11 | moyale
# Processing Record 32 of Set 11 | dohar
# Processing Record 33 of Set 11 | torit
# Processing Record 34 of Set 11 | boa vista
# Processing Record 35 of Set 11 | bermeo
# Processing Record 36 of Set 11 | jiamusi
# Processing Record 37 of Set 11 | torbat-e jam
# Processing Record 38 of Set 11 | tabou
# Processing Record 39 of Set 11 | severo-yeniseyskiy
# Processing Record 40 of Set 11 | evensk
# Processing Record 41 of Set 11 | joura
# Processing Record 42 of Set 11 | norman wells
# Processing Record 43 of Set 11 | leningradskiy
# Processing Record 44 of Set 11 | tilichiki
# Processing Record 45 of Set 11 | lahat
# Processing Record 46 of Set 11 | chiredzi
# Processing Record 47 of Set 11 | buala
# Processing Record 48 of Set 11 | flinders
# Processing Record 49 of Set 11 | vilyuysk
# Processing Record 0 of Set 12 | kenai
# Processing Record 1 of Set 12 | tasbuget
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 2 of Set 12 | fukue
# Processing Record 3 of Set 12 | khujand
# Processing Record 4 of Set 12 | young
# Processing Record 5 of Set 12 | saint-jovite
# Processing Record 6 of Set 12 | martapura
# Processing Record 7 of Set 12 | carikar
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 12 | bairiki
# Processing Record 9 of Set 12 | baruun-urt
# Processing Record 10 of Set 12 | san andres
# Processing Record 11 of Set 12 | sangmelima
# Processing Record 12 of Set 12 | selam
# Processing Record 13 of Set 12 | sistranda
# Processing Record 14 of Set 12 | ono
# Processing Record 15 of Set 12 | ciudad bolivar
# Processing Record 16 of Set 12 | igarape-acu
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 12 | acapulco
# Processing Record 18 of Set 12 | buncrana
# Processing Record 19 of Set 12 | pemba
# Processing Record 20 of Set 12 | tsaratanana
# Processing Record 21 of Set 12 | rawson
# Processing Record 22 of Set 12 | torbay
# Processing Record 23 of Set 12 | seoul
# Processing Record 24 of Set 12 | kilembe
# Processing Record 25 of Set 12 | maragogi
# Processing Record 26 of Set 12 | paragominas
# Processing Record 27 of Set 12 | paracale
# Processing Record 28 of Set 12 | urusha
# Processing Record 29 of Set 12 | beringovskiy
# Processing Record 30 of Set 12 | kumba
# Processing Record 31 of Set 12 | talcahuano
# Processing Record 32 of Set 12 | jiuquan
# Processing Record 33 of Set 12 | juneau
# Processing Record 34 of Set 12 | megion
# Processing Record 35 of Set 12 | fare
# Processing Record 36 of Set 12 | honiara
# Processing Record 37 of Set 12 | windhoek
# Processing Record 38 of Set 12 | tuatapere
# Processing Record 39 of Set 12 | aranos
# Processing Record 40 of Set 12 | itambe
# Processing Record 41 of Set 12 | ewa beach
# Processing Record 42 of Set 12 | jumla
# Processing Record 43 of Set 12 | umm kaddadah
# Processing Record 44 of Set 12 | port blair
# Processing Record 45 of Set 12 | saint pete beach
# Processing Record 46 of Set 12 | sorland
# Processing Record 47 of Set 12 | gilazi
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 48 of Set 12 | toowoomba
# Processing Record 49 of Set 12 | ati
# Processing Record 0 of Set 13 | meulaboh
# Processing Record 1 of Set 13 | salinopolis
# Processing Record 2 of Set 13 | sangar
# Processing Record 3 of Set 13 | siderno
# Processing Record 4 of Set 13 | winsum
# Processing Record 5 of Set 13 | dunmore town
# Processing Record 6 of Set 13 | mocuba
# Processing Record 7 of Set 13 | santa rosa
# Processing Record 8 of Set 13 | maracaibo
# Processing Record 9 of Set 13 | whitley bay
# Processing Record 10 of Set 13 | pangkalanbuun
# Processing Record 11 of Set 13 | mount gambier
# Processing Record 12 of Set 13 | sidoarjo
# Processing Record 13 of Set 13 | kamenskoye
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 14 of Set 13 | pyaozerskiy
# Processing Record 15 of Set 13 | limoux
# Processing Record 16 of Set 13 | tessalit
# Processing Record 17 of Set 13 | cianjur
# Processing Record 18 of Set 13 | khash
# Processing Record 19 of Set 13 | loukhi
# Processing Record 20 of Set 13 | henties bay
# Processing Record 21 of Set 13 | fort nelson
# Processing Record 22 of Set 13 | labuhan
# Processing Record 23 of Set 13 | khandyga
# Processing Record 24 of Set 13 | maceio
# Processing Record 25 of Set 13 | sioux lookout
# Processing Record 26 of Set 13 | palmer
# Processing Record 27 of Set 13 | lebowakgomo
# Processing Record 28 of Set 13 | pashiya
# Processing Record 29 of Set 13 | ust-kuyga
# Processing Record 30 of Set 13 | argentan
# Processing Record 31 of Set 13 | jinka
# Processing Record 32 of Set 13 | kaeo
# Processing Record 33 of Set 13 | shingu
# Processing Record 34 of Set 13 | linhares
# Processing Record 35 of Set 13 | iquique
# Processing Record 36 of Set 13 | briceni
# Processing Record 37 of Set 13 | shihezi
# Processing Record 38 of Set 13 | bani
# Processing Record 39 of Set 13 | hofn
# Processing Record 40 of Set 13 | omboue
# Processing Record 41 of Set 13 | margate
# Processing Record 42 of Set 13 | matara
# Processing Record 43 of Set 13 | felidhoo
# City not found. Skipping ...
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSON into Pandas
city_data_df = pd.DataFrame(city_data)


# Extract relevant fields from the data frame
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Windspeed"]

city_data_df.to_csv("../data/city_data.csv", index_label="City_ID")

city_data_df.count()
# Out:
# City          600
# Lat           600
# Lng           600
# Max Temp      600
# Humidity      600
# Cloudiness    600
# Windspeed     600
# Country       600
# Date          600
# dtype: int64

# %%
# Display the city Data Frame
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          albany  42.6001  -73.9662     53.28        83         100
# 1         ushuaia -54.8000  -68.3000     58.66        45           0
# 2  cabo san lucas  22.8909 -109.9124     82.76        75          20
# 3          hobart -42.8794  147.3294     52.05        91          98
# 4    longyearbyen  78.2186   15.6401     28.24        64          75
#
#    Windspeed Country        Date
# 0       0.85      US  1697638361
# 1      10.36      AR  1697638567
# 2       6.91      MX  1697638621
# 3       5.75      AU  1697638502
# 4      12.66      SJ  1697638649

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats,
            max_temps,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save figure
plt.savefig("../Python_API/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build scatter plot for latitude vs. Humidity
plt.scatter(lats,
            humidity,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
plt.savefig("../Python_API/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build scatter plot for latitude vs. Cloudiness
plt.scatter(lats,
            cloudiness,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
plt.savefig("../Python_API/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. Windspeed
plt.scatter(lats,
            wind_speed,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Windspeed mph")
plt.xlabel("Latitude")
plt.grid(True)


# Save figure
plt.savefig("../Python_API/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r-squared is: -0.881478267312537

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.6940654590813452

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-squared is: 0.20565940485858655

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.07922289003513346

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.11248611240599068

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.12841316574284808

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (40,25))
# Out:
# The r-squared is: 0.2497450580827231

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Windspeed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (-30,30))
# Out:
# The r-squared is: -0.24781074417768753
